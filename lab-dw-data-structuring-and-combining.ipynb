# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
#link1= https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#link2= https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
#link3= https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
import pandas as pd
df_1= pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv")
df_2= pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv")
df_3= pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv")

# %%
df_1.columns= df_1.columns.str.lower().str.replace(" ","_")
df_1= df_1.rename(columns={"st":"state"})
df_1
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df_2.columns= df_2.columns.str.lower().str.replace(" ","_")
df_2= df_2.rename(columns={"st":"state"})
df_2
# Out:
#     customer       state gender education customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# ...

# %%
df_3.columns= df_3.columns.str.lower().str.replace(" ","_")
df_3= df_3.rename(columns={"st":"state"})
df_3
# Out:
#      customer       state  customer_lifetime_value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
# combine 3 datasets
insurance_df= pd.concat([df_1,df_2,df_3], axis=0)
insurance_df
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
insurance_df.isnull()
# Out:
#       customer  state  gender  education  customer_lifetime_value  income  \
# 0        False  False    True      False                     True   False
# 1        False  False   False      False                    False   False
# 2        False  False   False      False                    False   False
# 3        False  False   False      False                    False   False
# 4        False  False   False      False                    False   False
# ...        ...    ...     ...        ...                      ...     ...
# 7065     False  False   False      False                    False   False
# 7066     False  False   False      False                    False   False
# 7067     False  False   False      False                    False   False
# 7068     False  False   False      False                    False   False
# 7069     False  False   False      False                    False   False
#
#       monthly_premium_auto  number_of_open_complaints  policy_type  \
# ...

# %%
# stadarize values in gender F, M
insurance_df["gender"]=insurance_df["gender"].map({"Female": "F", "Male": "M","Femal": "F" })
insurance_df["gender"].unique()
# Out:
# array([nan, 'F', 'M'], dtype=object)

# %%
insurance_df["education"]=insurance_df["education"].map({"bachelors": "bachelor"})
insurance_df["education"].unique()
# Out:
# array([nan], dtype=object)

# %%
insurance_df["customer_lifetime_value"] = insurance_df["customer_lifetime_value"].str.replace("%","")
insurance_df["customer_lifetime_value"].unique()
# Out:
# array([nan, '697953.59', '1288743.17', ..., '568964.41', '368672.38',
#        '399258.39'], dtype=object)

# %%
insurance_df["vehicle_class"]=insurance_df["vehicle_class"].map({"Luxury SUV": "luxury", "Luxury Car": "luxury", "Sports car": "Luxury"})
insurance_df["vehicle_class"].unique()
# Out:
# array([nan, 'luxury'], dtype=object)

# %%
insurance_df["number_of_open_complaints"]=insurance_df["number_of_open_complaints"].map({"1/0/00": "0", "1/2/00": "2", "/1/00": "1", "1/2/00": "2", "/1/00": "1", "1/3/00": "3", "1/5/00": "5", "1/4/00": "4"})
insurance_df["number_of_open_complaints"].unique()
insurance_df
# Out:
#      customer       state gender education customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN       NaN                     NaN      0.0
# 1     QZ44356     Arizona    NaN       NaN               697953.59      0.0
# 2     AI49188      Nevada    NaN       NaN              1288743.17  48767.0
# 3     WW63253  California    NaN       NaN               764586.18      0.0
# 4     GA49547  Washington    NaN       NaN               536307.65  36357.0
# ...       ...         ...    ...       ...                     ...      ...
# 7065  LA72316  California    NaN       NaN                     NaN  71941.0
# 7066  PK87824  California    NaN       NaN                     NaN  21604.0
# 7067  TD14365  California    NaN       NaN                     NaN      0.0
# 7068  UP19263  California    NaN       NaN                     NaN  21941.0
# 7069  Y167826  California    NaN       NaN                     NaN      0.0
#
# ...

# %%
insurance_df["number_of_open_complaints"].value_counts()
# Out:
# number_of_open_complaints
# 0    1626
# 2      93
# 3      60
# 4      29
# 5      12
# Name: count, dtype: int64

# %%
insurance_df.isnull()
# Out:
#       customer  state  gender  education  customer_lifetime_value  income  \
# 0        False  False    True       True                     True   False
# 1        False  False    True       True                    False   False
# 2        False  False    True       True                    False   False
# 3        False  False    True       True                    False   False
# 4        False  False    True       True                    False   False
# ...        ...    ...     ...        ...                      ...     ...
# 7065     False  False    True       True                     True   False
# 7066     False  False    True       True                     True   False
# 7067     False  False    True       True                     True   False
# 7068     False  False    True       True                     True   False
# 7069     False  False    True       True                     True   False
#
#       monthly_premium_auto  number_of_open_complaints  policy_type  \
# ...

# %%
insurance_df.isnull() .sum()
# Out:
# customer                      2937
# state                         2937
# gender                       12017
# education                    12074
# customer_lifetime_value      10014
# income                        2937
# monthly_premium_auto          2937
# number_of_open_complaints    10254
# policy_type                   2937
# vehicle_class                11731
# total_claim_amount            2937
# dtype: int64

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
# Your code goes here
import pandas as pd
demographics_dt= pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv")
demographics_dt.sample(5)
# Out:
#        unnamed:_0 customer   state  customer_lifetime_value response  \
# 9208         9208  FD11364  Oregon              6768.997027       No
# 8940         8940  MB83663  Oregon              9597.474777       No
# 9893         9893  NB86692  Nevada              2690.477161       No
# 10377       10377  NI44621  Oregon              9880.385820       No
# 3997         3997  HH49391  Oregon              9414.943031       No
#
#        coverage             education effective_to_date employmentstatus  \
# 9208   Extended              Bachelor        2011-01-31         Employed
# 8940   Extended              Bachelor        2011-02-18         Employed
# 9893      Basic               College        2011-01-02         Employed
# 10377  Extended                Master        2011-01-03         Employed
# 3997   Extended  High School or Below        2011-01-10          Retired
#
#       gender  ...  number_of_policies    policy_type       policy  \
# ...

# %%
demographics_dt.shape
# Out:
# (10910, 27)

# %%
demographics_dt.nunique()
# Out:
# unnamed:_0                       10910
# customer                          9134
# state                                5
# customer_lifetime_value           8041
# response                             2
# coverage                             3
# education                            5
# effective_to_date                   59
# employmentstatus                     5
# gender                               2
# income                            5694
# location_code                        3
# marital_status                       3
# monthly_premium_auto               202
# months_since_last_claim             37
# months_since_policy_inception      100
# number_of_open_complaints            7
# number_of_policies                   9
# policy_type                          3
# policy                               9
# renew_offer_type                     4
# sales_channel                        4
# total_claim_amount                5106
# vehicle_class                        6
# ...

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
sales_df=demographics_dt.pivot_table(columns= "sales_channel", values= ["income"])
sales_df = sales_df.round(2)
sales_df
# Out:
# sales_channel     Agent    Branch  Call Center       Web
# income         37003.19  37649.11     37858.48  38253.45

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
average_df = demographics_dt.pivot_table(index="gender", columns="education", values="customer_lifetime_value", aggfunc="mean")
average_df
# Out:
# education     Bachelor      College       Doctor  High School or Below  \
# gender
# F          7874.269478  7748.823325  7328.508916           8675.220201
# M          7703.601675  8052.459288  7415.333638           8149.687783
#
# education       Master
# gender
# F          8157.053154
# M          8168.832659

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here
